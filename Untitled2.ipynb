# %%
# %load_ext autoreload
# %reload_ext autoreload
# %autoreload 1

# %aimport eds_reader
from eds_reader import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
file = '../../../Desktop/260323_aldh7a1_taileye_0319.eds'
debug_eds(file)
# Out:
# === Files in archive ===
#   Manifest.mf
#   apldbio/sds/Manifest.mf
#   apldbio/sds/analysis_protocol.xml
#   apldbio/sds/calibrations/background.ini
#   apldbio/sds/calibrations/puredye.ini
#   apldbio/sds/calibrations/roi.ini
#   apldbio/sds/calibrations/uniformity.ini
#   apldbio/sds/eui_run.log
#   apldbio/sds/experiment.xml
#   apldbio/sds/export_setting.xml
#   apldbio/sds/extensions/Tamper
#   apldbio/sds/filterdata.xml
#   apldbio/sds/messages.log
#   apldbio/sds/multicomponentdata.xml
#   apldbio/sds/notification_setting.xml
#   apldbio/sds/plate_setup.ini
#   apldbio/sds/plate_setup.xml
#   apldbio/sds/puredyematrix.txt
#   apldbio/sds/quant/S01_C001_T01_P0001_M1_X1_E1.quant
#   apldbio/sds/quant/S01_C001_T01_P0001_M1_X1_E2.quant
#   apldbio/sds/quant/S01_C001_T01_P0001_M1_X1_E3.quant
#   apldbio/sds/quant/S01_C001_T01_P0001_M2_X2_E1.quant
#   apldbio/sds/quant/S01_C001_T01_P0001_M2_X2_E2.quant
#   apldbio/sds/quant/S01_C001_T01_P0001_M3_X3_E1.quant
# ...

# %%
debug_eds
# Out:
# <module 'eds_reader' from '/Users/jadelau/Development/Neuroscience/B6 Epilepsies/eds_reader.py'>

# %%
read_eds(file)
# Out:
#     Well Well Position    Sample  Allele 1  Allele 2 Call
# 0      1            A1      Gene  0.029467  0.133102
# 1      2            A2      Gene -0.003241  0.215954
# 2      3            A3      Gene  0.007945  0.070028
# 3      4            A4      Gene  0.007274  0.057991
# 4      5            A5      Gene -0.006222  0.343640
# ..   ...           ...       ...       ...       ...  ...
# 91    92            H8  Gene_HOM -0.001820  0.270078
# 92    93            H9  Gene_HOM -0.001574  0.276803
# 93    94           H10                 NaN       NaN
# 94    95           H11                 NaN       NaN
# 95    96           H12                 NaN       NaN
#
# [96 rows x 6 columns]
