# %%
# %load_ext autoreload
# %reload_ext autoreload
# %autoreload 1

# %aimport b6_epilepsies 
import b6_epilepsies as b6 #.py file in the same dir as this .ipynb
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
csv_file = 'KASP/241122_16_ALDH7A1_Genotyping Result_20241122_194145.csv'  # Replace with your CSV file pat
omitted_wells = ['D8', 'B12']  # Specify omitted wells
# drop = ['F6', 'F7'] #These are empty and skewing results

results = b6.KASP(csv_file, omitted_wells)
# results.produce_geno_file()

# %%
csv_file = 'KASP/241122_17_PLPBP_Genotyping Result_20241122_194227.csv'  # Replace with your CSV file pat
omitted_wells = ['F7', 'A12', 'C4', 'E12', 'D1']  # Specify omitted wells
# drop = ['F6', 'F7'] #These are empty and skewing results

results = b6.KASP(csv_file, omitted_wells)

# %%
csv_file = 'KASP/241129_14_PLPBP_Genotyping Result_20241129_212211.csv'  # Replace with your CSV file pat
omitted_wells = ['G12','G1','C5','F12','E9','D2','F10','B12','E1']  # Specify omitted wells
drop = ['E7','C3','C2'] #These are empty and skewing results

results = b6.KASP(csv_file, omitted_wells, drop)

# %%
csv_file = 'KASP/241108_16_17_PNPO_PTZ_01_Genotyping Result_20241108_203803.csv'  # Replace with your CSV file pat
omitted_wells = ['D1','E1','H1','D6','D8']  # Specify omitted wells
# drop = ['F6', 'F7'] #These are empty and skewing results

results = b6.KASP(csv_file, omitted_wells)

# %%
csv_file = 'KASP/241101_ALDH7A1_PTZ_Genotyping Result_20241203_140911.csv'  # Replace with your CSV file pat
omitted_wells = ['']  # Specify omitted wells
drop = ['H6','B1'] #These are empty and skewing results

results = b6.KASP(csv_file, omitted_wells,drop)
# results.produce_geno_file()

# %%
csv_file = 'KASP/240927_ALDH7A1_17_Genotyping Result_20241203_135538.csv'  # Replace with your CSV file pat
omitted_wells = ['D3','D1','']  # Specify omitted wells
# drop = ['F6', 'F7'] #These are empty and skewing results

results = b6.KASP(csv_file, omitted_wells)
results.produce_geno_file('240917_17')
# Out:
# DataFrame saved to 240917_17

# %%
csv_file = 'KASP/241217_ALDH7A1_4dpf_FC1_Genotyping Result_20241217_201725.csv'  # Replace with your CSV file pat
omitted_wells = ['D1', 'A9','B1','H8','B8']  # Specify omitted wells
# drop = ['H6','B1'] #These are empty and skewing results

results = b6.KASP(csv_file, omitted_wells)

# To print grouped wells
# results.print_grouped_well_lists()

# %%
csv_file = 'KASP/241217_ALDH7A1_4dpf_FC2_Genotyping Result_20241217_201759.csv'  # Replace with your CSV file pat
omitted_wells = ['B1', 'B8','B10','C1','D1', 'D2','H5']
# drop = ['H6','B1'] #These are empty and skewing results

results = b6.KASP(csv_file, omitted_wells)

# To print grouped wells
results.print_grouped_well_lists()
# Out:
# WT:
#   A: 6, 7
#   B: 9
#   C: 5, 12
#   D: 6, 7
#   E: 1, 2, 4, 6, 8, 12
#   H: 1, 2, 3
# HET:
#   A: 1, 3, 5, 8, 9, 11, 12
#   B: 3, 7, 12
#   C: 2, 6, 8, 9, 10, 11
#   D: 3, 5, 8, 9, 10, 11, 12
#   E: 3, 5, 7
#   H: 4, 6
# HOM:
#   A: 2, 4, 10
#   B: 2, 4, 5, 6, 11
#   C: 3, 4, 7
#   D: 4
#   E: 9, 10, 11
#   F: 1
#   H: 7, 8, 9
# Omitted:
#   B: 1, 8, 10
#   C: 1
#   D: 1, 2
#   H: 5
# Dropped:

# %%
csv_file = 'KASP/241219_16_17_PLPBP_PTZ 1_Genotyping Result_20241219_193843.csv'  # Replace with your CSV file pat
omitted_wells = ['H6', 'D1', 'A1','H1']
# drop = ['H6','B1'] #These are empty and skewing results

results = b6.KASP(csv_file, omitted_wells)

# To print grouped wells
# results.print_grouped_well_lists()

# %%
csv_file = 'KASP/241222_14_PLPBP_Genotyping Result_20241222_231945.csv'  # Replace with your CSV file pat
omitted_wells = ['C12', 'D12','H5','H1','A12','G12','A8','E11','H4']
# drop = ['H12','B1'] #These are empty and skewing results

results = b6.KASP(csv_file, omitted_wells)

# To print grouped wells
results.print_grouped_well_lists()
# Out:
# WT:
#   A: 3, 5, 6, 7, 9, 11
#   B: 1, 4, 8
#   C: 3, 5, 10, 11
#   D: 7, 9
#   E: 5, 6, 12
#   F: 1, 2, 3, 9, 11
#   G: 1, 6, 10, 11
#   H: 2, 3
# HET:
#   A: 2, 4, 10
#   B: 2, 3, 5, 6, 7, 9, 10, 11
#   C: 1, 2, 4, 7, 9
#   D: 1, 3, 4, 6, 8
#   E: 1, 4, 7, 8, 9, 10
#   F: 4, 6, 7, 10, 12
#   G: 2, 3, 4, 5, 7, 8, 9
#   H: 6
# HOM:
#   A: 1
#   B: 12
#   C: 6, 8
#   D: 2, 10, 11
#   E: 2, 3
#   F: 5, 8
#   H: 7, 8, 9
# Omitted:
#   A: 8, 12
#   C: 12
#   D: 12
#   E: 11
#   G: 12
#   H: 1, 4, 5
# Dropped:

# %%
csv_file = 'KASP/241222_15_PLPBP_Genotyping Result_20241222_231910.csv'  # Replace with your CSV file pat
omitted_wells = ['D1','C12','G3','D1','H5']
drop = ['H12','B12','D12','E12','H7','H8','H9','A12','C6']
# drop = ['H6','B12'] #These are empty and skewing results

results = b6.KASP(csv_file, omitted_wells,drop)

# To print grouped wells
results.print_grouped_well_lists()
# Out:
# WT:
#   B: 4, 6
#   C: 2, 3, 10
#   E: 4, 6, 9, 11
#   F: 3, 4, 6, 11, 12
#   G: 4, 7, 10
#   H: 1, 2, 3
# HET:
#   A: 1, 3, 4, 5, 6, 8, 9, 10
#   B: 1, 8, 9, 10, 11
#   C: 4, 8, 9, 11
#   D: 2, 6, 9, 10
#   E: 1, 2, 3, 5, 7, 8, 10
#   F: 2, 7, 8, 9, 10
#   G: 1, 5, 8, 9, 12
#   H: 4, 6
# HOM:
#   A: 2, 7, 11
#   B: 2, 3
#   D: 8, 11
#   G: 6, 11
# Omitted:
#   C: 12
#   D: 1
#   G: 3
#   H: 5
# Dropped:

# %%
csv_file = 'KASP/241118_14_ALDH7A1_Genotyping Result_20241118_160515.csv'  # Replace with your CSV file pat
omitted_wells = ['H7','A3','E8', 'D1','D3','G10','A7','G5']
drop = ['F7','F6'] #These are empty and skewing results

results = b6.KASP(csv_file, omitted_wells, drop)
results.data
# To print grouped wells
# results.print_grouped_well_lists()
# results.produce_geno_file('241105_14')
# Out:
# DataFrame saved to 241105_14

# %%
csv_file = 'KASP/250107_241215_14_PLPBP_Genotyping Result_20250107_152104.csv'  # Replace with your CSV file pat
omitted_wells = ['E1','E7','A2','H3','G1','G3','F1','H1']
drop = ['D1'] #These are empty and skewing results

results = b6.KASP(csv_file, omitted_wells, drop)
results.data
# To print grouped wells
# results.print_grouped_well_lists()
results.produce_geno_file('241215_14')
# Out:
# DataFrame saved to 241215_14

# %%
csv_file = 'KASP/250107_241215_15_PLPBP_Genotyping Result_20250107_151951.csv'  # Replace with your CSV file pat
omitted_wells = ['E7','D1','A1','A3','E12','F12','B12','G12','D12']
# drop = ['B12','G12','D12'] #These are empty and skewing results
drop = []
results = b6.KASP(csv_file, omitted_wells, drop)
results.data
# To print grouped wells
# results.print_grouped_well_lists()
# results.produce_geno_file('241212_15')

# [4.76010356 1.2179908  2.70970721] [1 2 0]
# Ref:  [ 1.4276378  -1.12060126]
# Out:
#     Well Well Position     Sample          Task  Confidence  Allele 1  \
# 0      1            A1      PLPBP       Unknown    0.987842  0.327910
# 1      2            A2      PLPBP       Unknown    0.987842  0.060869
# 2      3            A3      PLPBP       Unknown    0.987842  0.356642
# 3      4            A4      PLPBP       Unknown    0.987842  0.538463
# 4      5            A5      PLPBP       Unknown    0.987842  0.550789
# ..   ...           ...        ...           ...         ...       ...
# 76    89            H5  PLPBP_HET  Positive 1/2    0.987842  0.577284
# 77    90            H6  PLPBP_HET  Positive 1/2    0.987842  0.523004
# 78    91            H7  PLPBP_HOM  Positive 2/2    0.987842  0.097259
# 79    92            H8  PLPBP_HOM  Positive 2/2    0.987842  0.115301
# 80    93            H9  PLPBP_HOM  Positive 2/2    0.977880  0.151367
#
#     Allele 2           Call  Cluster Cluster Label    Color
# 0   0.035250      WT/mutant      NaN           NaN      NaN
# ...

# %%
csv_file = 'KASP/250122_0121_ALDH7A1_4dpf_FC_Genotyping Result_20250122_200321.csv'  # Replace with your CSV file pat
omitted_wells = ['C12','A3','B1','G5','B2','D11','C6','D8','C7']
drop = [] #These are empty and skewing results

results = b6.KASP(csv_file, omitted_wells, drop)
# results.data
# To print grouped wells
# results.print_grouped_well_lists()
# results.produce_geno_file('241212_15')

# %%
csv_file = 'KASP/250122_0121_ALDH7A1_4dpf_FC_01_Genotyping Result_20250122_200407.csv'  # Replace with your CSV file pat
omitted_wells = ['F8','C3','C4','H10','A1','C5','E7','H1','F7','C7','G11','G7','D1','G10','C12']
drop = [] #These are empty and skewing results

results = b6.KASP(csv_file, omitted_wells, drop)
# results.data
# To print grouped wells
# results.print_grouped_well_lists()
# results.produce_geno_file('241212_15')

# %%
csv_file = 'KASP/250124_25271_2612_SLC39A14_Genotyping Result_20250124_183240.csv'  # Replace with your CSV file pat
omitted_wells = []
drop = [] #These are empty and skewing results

results = b6.KASP(csv_file, omitted_wells, drop)
# results.data
# To print grouped wells
# results.print_grouped_well_lists()
# results.produce_geno_file('241212_15')

# %%
csv_file = 'KASP/250124_0121_ALDH7A1_4dpf_FC_Genotyping Result_20250124_183129.csv'  # Replace with your CSV file pat
omitted_wells = ['B9','F1','F10','F7','C12','G5','B2','A1']
drop = [] #These are empty and skewing results

results = b6.KASP(csv_file, omitted_wells, drop)
# results.data
# To print grouped wells
results.print_grouped_well_lists()
# results.produce_geno_file('241212_15')
# Out:
# WT:
#   A: 2, 4, 5, 7, 10
#   B: 4, 5
#   C: 3, 6, 10
#   D: 8, 11
#   E: 12
#   F: 6, 12
#   G: 9
#   H: 1, 2, 3
# HET:
#   A: 3, 6, 8, 9, 11, 12
#   B: 1, 3, 6, 7, 8
#   C: 1, 2, 4, 7, 8, 9
#   D: 3, 5, 6, 7, 9, 10
#   E: 1, 2, 3, 5, 7, 9, 10, 11
#   F: 3, 4, 8, 9, 11
#   G: 2, 3, 4, 10
#   H: 4, 5, 6, 12
# HOM:
#   B: 10, 11, 12
#   C: 5, 11
#   D: 1, 2, 4, 12
#   E: 4, 6, 8
#   F: 2, 5
#   G: 1, 6, 7, 8, 11
#   H: 7, 8, 9, 10, 11
# Omitted:
#   A: 1
#   B: 2, 9
#   C: 12
#   F: 1, 7, 10
#   G: 5
# Dropped:

# %%
csv_file = 'KASP/250204_14_PLPBP_Genotyping Result_20250204_145749.csv'  # Replace with your CSV file pat
omitted_wells = ['H9','A1','D3','D1','C6','B1','E1','G6']
drop = [] #These are empty and skewing results

results = b6.KASP(csv_file, omitted_wells, drop)
# results.data
# To print grouped wells
# results.print_grouped_well_lists()
# results.produce_geno_file('250121_14')

# %%
csv_file = 'KASP/250212_0211_PLPBP_4dpf_FC_Genotyping Result_20250212_172726.csv'  # Replace with your CSV file pat
omitted_wells = ['E1','G1','D11','G5','C1','C4','B1','A1','E7','B6','F1','D10','C5']
drop = [] #These are empty and skewing results

results = b6.KASP(csv_file, omitted_wells, drop)
# results.print_grouped_well_lists()
# results.produce_geno_file('250121_15')

# %%
csv_file = 'KASP/250217_0214_14_ALDH7A1_7dpf_Genotyping Result_20250217_195109.csv'  # Replace with your CSV file pat
omitted_wells = ['H7','D8','D9','D12']
drop = ['H10','H11','H12'] #These are empty and skewing results

results = b6.KASP(csv_file, omitted_wells, drop)
# results.print_grouped_well_lists()
# results.produce_geno_file('250121_15')

# %%
csv_files = [
    'KASP/250204_14_PLPBP_Genotyping Result_20250204_145749.csv',
    'KASP/250204_15_PLPBP_Genotyping Result_20250204_145839.csv'
]
# For plate 1 and plate 2 respectively.
omitted_wells = {1: ['H9','A1','D3','D1','C6','B1','E1','G6'], 2: ['H1', 'B1']}
drop = {1: [], 2: []}

results = b6.KASP(csv_files, omitted_wells, drop)
# results.produce_geno_file('250121_00', merged=True)

# %%
csv_file = 'KASP/250217_0214_16_PLPBP_7dpf_01_Genotyping Result_20250217_195245.csv'  # Replace with your CSV file pat
omitted_wells = ['H9','H12','G3']
drop = [] #These are empty and skewing results

results = b6.KASP(csv_file, omitted_wells, drop)
# results.print_grouped_well_lists()
# results.produce_geno_file('250121_15')

# %%
csv_file = 'KASP/250217_0214_17_PLPBP_7dpf_Genotyping Result_20250217_195341.csv'  # Replace with your CSV file pat
omitted_wells = ['G12','F12']
drop = [] #These are empty and skewing results

results = b6.KASP(csv_file, omitted_wells, drop)
# results.print_grouped_well_lists()
# results.produce_geno_file('250121_15')
